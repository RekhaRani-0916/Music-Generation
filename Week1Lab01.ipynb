# %%
# E21CSSEU0916
# Rekha Rani

import numpy as np
import pandas as pd
from sklearn import preprocessing

# %%
data_set = pd.read_csv("D:\Downloads Folder\multiple_linear_data.csv")
data_set.head()
# Out:
#    age address famsize  reason  studytime  failures schoolsup famsup paid  \
# 0   18       U     GT3  course          2         0       yes     no   no
# 1   17       U     GT3  course          2         0        no    yes   no
# 2   15       U     LE3   other          2         3       yes     no  yes
# 3   15       U     GT3    home          3         0        no    yes  yes
# 4   16       U     GT3    home          2         0        no    yes  yes
#
#   activities higher internet romantic  freetime  goout  health  absences  G1  \
# 0         no    yes       no       no         3      4       3         6  25
# 1         no    yes      yes       no         3      3       3         4  25
# 2         no    yes      yes       no         3      2       3        10  35
# 3        yes    yes      yes      yes         2      2       5         2  75
# 4         no    yes       no       no         3      2       5         4  30
#
#    G2  G3
# 0  30  30
# 1  25  30
# 2  40  50
# 3  70  75
# ...

# %%
data_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 20 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   age         395 non-null    int64
#  1   address     395 non-null    object
#  2   famsize     395 non-null    object
#  3   reason      395 non-null    object
#  4   studytime   395 non-null    int64
#  5   failures    395 non-null    int64
#  6   schoolsup   395 non-null    object
#  7   famsup      395 non-null    object
#  8   paid        395 non-null    object
#  9   activities  395 non-null    object
#  10  higher      395 non-null    object
#  11  internet    395 non-null    object
#  12  romantic    395 non-null    object
#  13  freetime    395 non-null    int64
#  14  goout       395 non-null    int64
#  15  health      395 non-null    int64
#  16  absences    395 non-null    int64
#  17  G1          395 non-null    int64
#  18  G2          395 non-null    int64
# ...

# %%
label_encoder = preprocessing.LabelEncoder()
label_encoder.fit(data_set["address"])
# Out:
# LabelEncoder()

# %%
print(list(label_encoder.classes_))
print()
# Out:
# ['R', 'U']

# %%
data_set["address"] = label_encoder.transform(data_set["address"])

# %%
data_set.head()
# Out:
#    age  address famsize  reason  studytime  failures schoolsup famsup paid  \
# 0   18        1     GT3  course          2         0       yes     no   no
# 1   17        1     GT3  course          2         0        no    yes   no
# 2   15        1     LE3   other          2         3       yes     no  yes
# 3   15        1     GT3    home          3         0        no    yes  yes
# 4   16        1     GT3    home          2         0        no    yes  yes
#
#   activities higher internet romantic  freetime  goout  health  absences  G1  \
# 0         no    yes       no       no         3      4       3         6  25
# 1         no    yes      yes       no         3      3       3         4  25
# 2         no    yes      yes       no         3      2       3        10  35
# 3        yes    yes      yes      yes         2      2       5         2  75
# 4         no    yes       no       no         3      2       5         4  30
#
#    G2  G3
# 0  30  30
# 1  25  30
# 2  40  50
# ...

# %%
from sklearn.model_selection import cross_val_predict
y_train_pred = cross_val_predict(sgd_clf, X_train, y_train_5, cv=3)

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_train_5, y_train_pred)

# %%
def linear_model_main(x_parameters, y_parameters, predict_value):
    # Create linear regression object
    regr = linear_model.LinearRegression()<
    regr.fit(x_parameters, y_parameters)
    
    predict_outcome = regr.predict(predict_value)
    score = regr.score(X, Y)
    predictions = {'intercept': regr.intercept_, 'coefficient': regr.coef_,   'predicted_value': predict_outcome, 'accuracy' : score}
    return predictions

predicted_value = 9 #I NEED TO PREDICT 9,10,11,12,13,14,15

result = linear_model_main(X, Y, predicted_value)
print('Constant Value: {0}'.format(result['intercept']))
print('Coefficient: {0}'.format(result['coefficient']))
print('Predicted Value: {0}'.format(result['predicted_value']))
print('Accuracy: {0}'.format(result['accuracy']))
